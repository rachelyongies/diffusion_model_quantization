# %% [markdown]
# # 03 - Quantization Implementation
#
# Implement different quantization levels and measure performance.

# %%
import os
import json
import config as cfg

# %% [markdown]
# ## TODO: Add implementation

# %%
# Add your code here
pass
